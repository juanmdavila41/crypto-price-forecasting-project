# %% [markdown]
# ## Setup and Initialization

# %%
import pandas as pd
import re
import numpy as np
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import requests
from bs4 import BeautifulSoup
from datetime import datetime, date

# Download the VADER lexicon
nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\windows\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ## Define Function to Scrape News

# %%
def get_news(ticker, pages=1):
    base_url = f"https://cointelegraph.com/tags/{ticker}"
    all_news = []
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36'
    }

    for page in range(1, pages + 1):
        response = requests.get(base_url + f"?page={page}", headers=headers)
        soup = BeautifulSoup(response.content, 'html5lib')
        articles = soup.find_all('li', class_='group-[.inline]:mb-8 col-span-1')

        for article in articles:
            try:
                commercial_name = ticker
                title = article.find('span', class_='post-card-inline__title').text.strip()
                date_element = article.find('time', class_='post-card-inline__date')
                date = date_element['datetime'] if date_element else None

                all_news.append({
                    'commercial_name': commercial_name,
                    'title': title,
                    'date': date
                })
            except Exception as e:
                continue

    return pd.DataFrame(all_news)

# %% [markdown]
# ## Define Cryptocurrency List and Mapping

# %%
# List of cryptocurrencies
cryptocurrency_names = ['bitcoin', 'ethereum', 'cardano']
crypto_code_mapping = {
    'bitcoin': 'BTC-USD',
    'ethereum': 'ETH-USD',
    'cardano': 'ADA-USD'
}

# %% [markdown]
# ## News for Each Cryptocurrency

# %%
# List to store all news data
all_news = []

# %%
for ticker in cryptocurrency_names:
    news_df = get_news(ticker, pages=50)
    all_news.append(news_df)
    print(f'News for {ticker} successfully downloaded.')
# Out:
# News for bitcoin successfully downloaded.
# News for ethereum successfully downloaded.
# News for cardano successfully downloaded.

# %%
# Combine all news DataFrames into a single DataFrame
combined_news_df = pd.concat(all_news)
combined_news_df['crypto_code'] = np.where(
    combined_news_df['commercial_name'].isin(crypto_code_mapping.keys()),
    combined_news_df['commercial_name'].map(crypto_code_mapping),
    np.nan  # Assign NaN if the symbol is not in the dictionary
)

# %% [markdown]
# ## Preprocessing and Tokenization

# %%
# Preprocessing and tokenization
combined_news_df['cleaned_title'] = combined_news_df['title'].apply(lambda x: ' '.join(re.findall(r'\b\w+\b', x.lower())))
# Remove apostrophes
combined_news_df['cleaned_title'] = combined_news_df['cleaned_title'].str.replace(r"n't", " not")

# %%
combined_news_df
# Out:
#     commercial_name                                              title  \
# 0           bitcoin  How 1,500 new Bitcoin millionaires per day dea...
# 1           bitcoin               Here’s what happened in crypto today
# 2           bitcoin  Traders say Bitcoin price fights ‘last resista...
# 3           bitcoin  Bitcoin price aims for $69K as ‘hot’ US macro ...
# 4           bitcoin  Exclusive: Joe Lubin unpacks SEC battle, Ether...
# ..              ...                                                ...
# 745         cardano  President Joe Biden is trying hard to ‘kill cr...
# 746         cardano  Price analysis 5/8: BTC, ETH, BNB, SOL, XRP, D...
# 747         cardano  Price analysis 5/6: SPX, DXY, BTC, ETH, BNB, S...
# 748         cardano           Why is Cardano (ADA) price up this week?
# 749         cardano  Cardano founder proposes Bitcoin Cash integrat...
#
#            date crypto_code                                      cleaned_title
# 0    2024-05-30     BTC-USD  how 1 500 new bitcoin millionaires per day dea...
# 1    2024-05-30     BTC-USD               here s what happened in crypto today
# 2    2024-05-30     BTC-USD  traders say bitcoin price fights last resistan...
# 3    2024-05-30     BTC-USD  bitcoin price aims for 69k as hot us macro dat...
# 4    2024-05-30     BTC-USD  exclusive joe lubin unpacks sec battle ethereu...
# ..          ...         ...                                                ...
# 745  2024-05-10     ADA-USD  president joe biden is trying hard to kill cry...
# 746  2024-05-08     ADA-USD  price analysis 5 8 btc eth bnb sol xrp doge to...
# 747  2024-05-06     ADA-USD  price analysis 5 6 spx dxy btc eth bnb sol xrp...
# 748  2024-05-06     ADA-USD              why is cardano ada price up this week
# 749  2024-05-05     ADA-USD  cardano founder proposes bitcoin cash integrat...
#
# [2250 rows x 5 columns]

# %% [markdown]
# ## Sentiment Analysis

# %%
# Calculate sentiment using VADER
combined_news_df['sentiment_SIA'] = combined_news_df['cleaned_title'].apply(lambda x: sid.polarity_scores(x)['compound'])
combined_news_df.to_csv('data/combined_crypto_news_with_sentiment.csv', sep=';', index=False)
print('Combined and analyzed news saved to combined_crypto_news_with_sentiment.csv')
# Out:
# Combined and analyzed news saved to combined_crypto_news_with_sentiment.csv

# %%
combined_news_df
# Out:
#     commercial_name                                              title  \
# 0           bitcoin  How 1,500 new Bitcoin millionaires per day dea...
# 1           bitcoin               Here’s what happened in crypto today
# 2           bitcoin  Traders say Bitcoin price fights ‘last resista...
# 3           bitcoin  Bitcoin price aims for $69K as ‘hot’ US macro ...
# 4           bitcoin  Exclusive: Joe Lubin unpacks SEC battle, Ether...
# ..              ...                                                ...
# 745         cardano  President Joe Biden is trying hard to ‘kill cr...
# 746         cardano  Price analysis 5/8: BTC, ETH, BNB, SOL, XRP, D...
# 747         cardano  Price analysis 5/6: SPX, DXY, BTC, ETH, BNB, S...
# 748         cardano           Why is Cardano (ADA) price up this week?
# 749         cardano  Cardano founder proposes Bitcoin Cash integrat...
#
#            date crypto_code  \
# 0    2024-05-30     BTC-USD
# 1    2024-05-30     BTC-USD
# 2    2024-05-30     BTC-USD
# 3    2024-05-30     BTC-USD
# 4    2024-05-30     BTC-USD
# ..          ...         ...
# 745  2024-05-10     ADA-USD
# 746  2024-05-08     ADA-USD
# 747  2024-05-06     ADA-USD
# 748  2024-05-06     ADA-USD
# 749  2024-05-05     ADA-USD
#
#                                          cleaned_title  sentiment_SIA
# 0    how 1 500 new bitcoin millionaires per day dea...         0.5574
# 1                 here s what happened in crypto today         0.0000
# 2    traders say bitcoin price fights last resistan...        -0.4019
# 3    bitcoin price aims for 69k as hot us macro dat...        -0.3182
# 4    exclusive joe lubin unpacks sec battle ethereu...        -0.2732
# ..                                                 ...            ...
# 745  president joe biden is trying hard to kill cry...        -0.7269
# 746  price analysis 5 8 btc eth bnb sol xrp doge to...         0.0000
# 747  price analysis 5 6 spx dxy btc eth bnb sol xrp...         0.0000
# 748              why is cardano ada price up this week         0.0000
# 749  cardano founder proposes bitcoin cash integrat...         0.0000
#
# [2250 rows x 6 columns]
