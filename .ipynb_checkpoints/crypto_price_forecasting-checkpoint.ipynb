# %% [markdown]
# ## Install Required Packages

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\windows\anaconda3\lib\site-packages (0.13.5)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\windows\anaconda3\lib\site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\windows\anaconda3\lib\site-packages (from statsmodels) (22.0)
# Requirement already satisfied: scipy>=1.3 in c:\users\windows\anaconda3\lib\site-packages (from statsmodels) (1.10.0)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\windows\anaconda3\lib\site-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in c:\users\windows\anaconda3\lib\site-packages (from statsmodels) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\windows\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\windows\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in c:\users\windows\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)

# %%
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in c:\users\windows\anaconda3\lib\site-packages (1.1.5)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\windows\anaconda3\lib\site-packages (from prophet) (1.5.3)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\windows\anaconda3\lib\site-packages (from prophet) (4.64.1)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\windows\anaconda3\lib\site-packages (from prophet) (3.7.0)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\windows\anaconda3\lib\site-packages (from prophet) (1.23.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\windows\anaconda3\lib\site-packages (from prophet) (1.2.2)
# Requirement already satisfied: holidays>=0.25 in c:\users\windows\anaconda3\lib\site-packages (from prophet) (0.49)
# Requirement already satisfied: importlib-resources in c:\users\windows\anaconda3\lib\site-packages (from prophet) (6.4.0)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in c:\users\windows\anaconda3\lib\site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.0)
# Requirement already satisfied: python-dateutil in c:\users\windows\anaconda3\lib\site-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\windows\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (22.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\windows\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\windows\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\windows\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\windows\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\windows\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\windows\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\windows\anaconda3\lib\site-packages (from pandas>=1.0.4->prophet) (2022.7)
# Requirement already satisfied: colorama in c:\users\windows\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\windows\anaconda3\lib\site-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)

# %% [markdown]
# ## Import Libraries

# %%
from datetime import date, datetime, timedelta
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from prophet import Prophet
from sklearn.metrics import mean_absolute_error, mean_squared_error
from prophet.diagnostics import cross_validation, performance_metrics

# %% [markdown]
# ## Load Price Data

# %%
# Load price data
df_price = pd.read_csv('data/combined_crypto_data.csv')
df_price = df_price[['Date', 'crypto_code', 'Adj Close']]
df_price = df_price.rename(columns= {'Date': 'date'})
df_price
# Out:
#             date crypto_code     Adj Close
# 0     2023-05-30     BTC-USD  27702.349609
# 1     2023-05-31     BTC-USD  27219.658203
# 2     2023-06-01     BTC-USD  26819.972656
# 3     2023-06-02     BTC-USD  27249.589844
# 4     2023-06-03     BTC-USD  27075.128906
# ...          ...         ...           ...
# 1093  2024-05-25     ADA-USD      0.462072
# 1094  2024-05-26     ADA-USD      0.458375
# 1095  2024-05-27     ADA-USD      0.467963
# 1096  2024-05-28     ADA-USD      0.456990
# 1097  2024-05-29     ADA-USD      0.450995
#
# [1098 rows x 3 columns]

# %% [markdown]
# ## Load Sentiment Data

# %%
# Load sentiment data
df_sentiment = pd.read_csv('data/combined_crypto_news_with_sentiment.csv', sep=';')
df_sentiment = df_sentiment[['date', 'crypto_code', 'title', 'sentiment_SIA']]
df_sentiment = df_sentiment.groupby(by=['date', 'crypto_code'], as_index=False).mean()
df_sentiment
# Out:
# C:\Users\windows\AppData\Local\Temp\ipykernel_1552\762760937.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_sentiment = df_sentiment.groupby(by=['date', 'crypto_code'], as_index=False).mean()
#           date crypto_code  sentiment_SIA
# 0   2024-05-05     ADA-USD       0.000000
# 1   2024-05-06     ADA-USD       0.000000
# 2   2024-05-08     ADA-USD       0.000000
# 3   2024-05-10     ADA-USD      -0.363450
# 4   2024-05-13     ADA-USD       0.000000
# 5   2024-05-15     ADA-USD       0.000000
# 6   2024-05-17     ADA-USD       0.000000
# 7   2024-05-20     ADA-USD       0.000000
# 8   2024-05-22     ADA-USD       0.000000
# 9   2024-05-24     ADA-USD       0.000000
# 10  2024-05-27     ADA-USD       0.000000
# 11  2024-05-29     BTC-USD       0.202300
# 12  2024-05-29     ETH-USD      -0.068000
# 13  2024-05-30     ADA-USD       0.000000
# 14  2024-05-30     BTC-USD      -0.024829
# 15  2024-05-30     ETH-USD      -0.072370

# %% [markdown]
# ## Merge Price and Sentiment Data

# %%
# Merge price and sentiment data
df = df_price.merge(df_sentiment, on=['date', 'crypto_code'], how='left')
df['date'] = pd.to_datetime(df['date'])
df = df.dropna(subset=['Adj Close'])
df
# Out:
#            date crypto_code     Adj Close  sentiment_SIA
# 0    2023-05-30     BTC-USD  27702.349609            NaN
# 1    2023-05-31     BTC-USD  27219.658203            NaN
# 2    2023-06-01     BTC-USD  26819.972656            NaN
# 3    2023-06-02     BTC-USD  27249.589844            NaN
# 4    2023-06-03     BTC-USD  27075.128906            NaN
# ...         ...         ...           ...            ...
# 1093 2024-05-25     ADA-USD      0.462072            NaN
# 1094 2024-05-26     ADA-USD      0.458375            NaN
# 1095 2024-05-27     ADA-USD      0.467963            0.0
# 1096 2024-05-28     ADA-USD      0.456990            NaN
# 1097 2024-05-29     ADA-USD      0.450995            NaN
#
# [1098 rows x 4 columns]

# %% [markdown]
# ## Forecast using Prophet with Sentiment

# %%
# Forecast using Prophet with Sentiment
for crypto_code in df['crypto_code'].unique():
    crypto_data = df[df['crypto_code'] == crypto_code]

    # Sort by date
    crypto_data = crypto_data.sort_values(by='date')

    # Ensure 'sentiment_SIA' column exists
    if 'sentiment_SIA' not in crypto_data.columns:
        raise ValueError(f"'sentiment_SIA' column does not exist in the data for {crypto_code}")

    # Create DataFrame for Prophet
    prophet_data = crypto_data.rename(columns={'date': 'ds', 'Adj Close': 'y', 'sentiment_SIA': 'sentiment'})

    # Handle missing values in 'sentiment' column
    prophet_data['sentiment'] = prophet_data['sentiment'].fillna(method='ffill').fillna(method='bfill')

    # Fill with a constant value if there are still missing values
    if prophet_data['sentiment'].isnull().any():
        print(f"{crypto_code}: Still have missing values after ffill and bfill.")
        prophet_data['sentiment'] = prophet_data['sentiment'].fillna(0)

    # Ensure 'y' column has no missing values and drop rows with null 'y'
    prophet_data = prophet_data.dropna(subset=['y'])

    # Check if there are enough data points to train the model
    if prophet_data.shape[0] < 2:
        print(f"Insufficient data to train Prophet model for {crypto_code}.")
        continue

    # Configure Prophet model
    model_prophet = Prophet()
    model_prophet.add_regressor('sentiment')  # Add sentiment as regressor

    # Fit Prophet model
    model_prophet.fit(prophet_data)

    # Forecast next 30 days
    future = model_prophet.make_future_dataframe(periods=7)
    future['sentiment'] = 0

    forecast_prophet = model_prophet.predict(future)

    # Evaluation Metrics
    # Assuming you have some historical data to compare with
    # For example, we use the last 30 days for evaluation
    y_true = prophet_data['y'].values[-7:]
    y_pred = forecast_prophet['yhat'].values[:7]

    # Calculate MAE
    mae = mean_absolute_error(y_true, y_pred)
    print(f'{crypto_code} - MAE: {mae}')

    # Calculate RMSE
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    print(f'{crypto_code} - RMSE: {rmse}')

    # Calculate MAPE
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    print(f'{crypto_code} - MAPE: {mape}')

    # Adjust cross-validation parameters
    initial_days = '180 days'  # Reduce initial window
    period_days = '90 days'    # Adjust period
    horizon_days = '15 days'   # Reduce horizon

    try:
        # Cross-Validation
        df_cv = cross_validation(model_prophet, initial=initial_days, period=period_days, horizon=horizon_days)
        df_p = performance_metrics(df_cv)
        print(df_p.head())
    except ValueError as e:
        print(f"Error in cross-validation for {crypto_code}: {e}")

    # Get date three months ago from the last date of historical data
    last_date = prophet_data['ds'].max()
    three_months_ago = last_date - pd.DateOffset(months=1)

    # Filter data to get only the last three months
    prophet_data_last_month = prophet_data[prophet_data['ds'] >= three_months_ago]
    forecast_prophet_last_month = forecast_prophet[forecast_prophet['ds'] >= three_months_ago]

    # Visualize results
    plt.figure(figsize=(10, 6))

    # Plot history of the last three months
    plt.plot(prophet_data_last_month['ds'], prophet_data_last_month['y'], color='gray', label='History')

    # Plot forecast of the last three months
    plt.plot(forecast_prophet_last_month['ds'], forecast_prophet_last_month['yhat'], color='blue', label='Forecast')

    plt.xlabel('Date')
    plt.ylabel('Closing Price')
    plt.title(f'Price Forecast of {crypto_code} using Prophet with Sentiment')
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# 20:33:02 - cmdstanpy - INFO - Chain [1] start processing
# 20:33:02 - cmdstanpy - INFO - Chain [1] done processing
# BTC-USD - MAE: 41122.91542526938
# BTC-USD - RMSE: 41129.99711187453
# BTC-USD - MAPE: 60.02751750546659
#   0%|          | 0/2 [00:00<?, ?it/s]
# 20:33:03 - cmdstanpy - INFO - Chain [1] start processing
# 20:33:03 - cmdstanpy - INFO - Chain [1] done processing
# 20:33:03 - cmdstanpy - INFO - Chain [1] start processing
# 20:33:03 - cmdstanpy - INFO - Chain [1] done processing
#   horizon           mse         rmse          mae      mape     mdape  \
# 0  2 days  2.478278e+07  4978.230985  3727.071835  0.070659  0.015906
# 1  3 days  2.410512e+07  4909.696413  4079.191358  0.075574  0.030981
# 2  4 days  2.600538e+07  5099.547422  4503.746495  0.082089  0.031931
# 3  5 days  2.367881e+07  4866.088059  4136.519936  0.076316  0.031931
# 4  6 days  3.530033e+07  5941.407738  5616.058411  0.096235  0.085854
#
#       smape  coverage
# 0  0.075540  0.500000
# 1  0.080246  0.500000
# 2  0.087052  0.500000
# 3  0.080900  0.500000
# 4  0.101970  0.166667
# 20:33:04 - cmdstanpy - INFO - Chain [1] start processing
# 20:33:04 - cmdstanpy - INFO - Chain [1] done processing
# ETH-USD - MAE: 1900.3055184202206
# ETH-USD - RMSE: 1901.3707496526604
# ETH-USD - MAPE: 50.04250267552077
#   0%|          | 0/2 [00:00<?, ?it/s]
# 20:33:05 - cmdstanpy - INFO - Chain [1] start processing
# 20:33:05 - cmdstanpy - INFO - Chain [1] done processing
# 20:33:05 - cmdstanpy - INFO - Chain [1] start processing
# 20:33:05 - cmdstanpy - INFO - Chain [1] done processing
#   horizon            mse        rmse         mae      mape     mdape  \
# 0  2 days   53327.819234  230.928169  187.417597  0.066211  0.025667
# 1  3 days   48873.423720  221.073345  193.576900  0.068006  0.030007
# 2  4 days   71912.750641  268.165528  238.924906  0.081945  0.043723
# 3  5 days   97016.768930  311.475150  262.817798  0.088960  0.043723
# 4  6 days  271993.517316  521.529977  482.136397  0.147315  0.169745
#
#       smape  coverage
# 0  0.069553  0.500000
# 1  0.071156  0.500000
# 2  0.086551  0.500000
# 3  0.095025  0.500000
# 4  0.160870  0.166667
# 20:33:06 - cmdstanpy - INFO - Chain [1] start processing
# 20:33:06 - cmdstanpy - INFO - Chain [1] done processing
# ADA-USD - MAE: 0.14387047258715663
# ADA-USD - RMSE: 0.14397778013190618
# ADA-USD - MAPE: 31.255338990580604
#   0%|          | 0/2 [00:00<?, ?it/s]
# 20:33:06 - cmdstanpy - INFO - Chain [1] start processing
# 20:33:06 - cmdstanpy - INFO - Chain [1] done processing
# 20:33:07 - cmdstanpy - INFO - Chain [1] start processing
# 20:33:07 - cmdstanpy - INFO - Chain [1] done processing
#   horizon       mse      rmse       mae      mape     mdape     smape  \
# 0  2 days  0.003802  0.061659  0.044596  0.074642  0.013385  0.080266
# 1  3 days  0.004352  0.065973  0.054177  0.093238  0.054878  0.099826
# 2  4 days  0.005835  0.076387  0.066169  0.113857  0.060745  0.122576
# 3  5 days  0.007126  0.084417  0.069889  0.117322  0.060745  0.127543
# 4  6 days  0.007793  0.088276  0.079233  0.135476  0.106161  0.147174
#
#    coverage
# 0       0.5
# 1       0.5
# 2       0.5
# 3       0.5
# 4       0.5

# %% [markdown]
# ## Forecast using Prophet without Sentiment

# %%
# Forecast using Prophet without Sentiment
for crypto_code in df['crypto_code'].unique():
    crypto_data_no_sentiment = df[df['crypto_code'] == crypto_code]
    
    # Renombrar columnas del DataFrame
    crypto_data_no_sentiment = crypto_data_no_sentiment.rename(columns={'date': 'ds', 'Adj Close': 'y'})

    # Sort by date
    crypto_data_no_sentiment = crypto_data_no_sentiment.sort_values(by='ds')

    # Ensure 'y' column has no missing values and drop rows with null 'y'
    crypto_data_no_sentiment = crypto_data_no_sentiment.dropna(subset=['y'])
    
    # Check if there are enough data points to train the model
    if crypto_data_no_sentiment.shape[0] < 2:
        print(f"Insufficient data to train Prophet model for {crypto_code}.")
        continue

    # Configure Prophet model without sentiment
    model_prophet_no_sentiment = Prophet()

    # Fit Prophet model
    model_prophet_no_sentiment.fit(crypto_data_no_sentiment)

    # Forecast next 30 days without sentiment
    future_no_sentiment = model_prophet_no_sentiment.make_future_dataframe(periods=7)
    forecast_prophet_no_sentiment = model_prophet_no_sentiment.predict(future_no_sentiment)

    # Evaluation Metrics
    # Assuming you have some historical data to compare with
    # For example, we use the last 30 days for evaluation
    y_true = crypto_data_no_sentiment['y'].values[-7:]
    y_pred = forecast_prophet_no_sentiment['yhat'].values[:7]

    # Calculate MAE
    mae = mean_absolute_error(y_true, y_pred)
    print(f'{crypto_code} - MAE: {mae}')

    # Calculate RMSE
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    print(f'{crypto_code} - RMSE: {rmse}')

    # Calculate MAPE
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    print(f'{crypto_code} - MAPE: {mape}')

    # Adjust cross-validation parameters
    initial_days = '180 days'  # Reduce initial window
    period_days = '90 days'    # Adjust period
    horizon_days = '15 days'   # Reduce horizon

    try:
        # Cross-Validation
        df_cv = cross_validation(model_prophet_no_sentiment, initial=initial_days, period=period_days, horizon=horizon_days)
        df_p = performance_metrics(df_cv)
        print(df_p.head())
    except ValueError as e:
        print(f"Error in cross-validation for {crypto_code}: {e}")

    # Get date three months ago from the last date of historical data
    last_date_no_sentiment = crypto_data_no_sentiment['ds'].max()
    three_months_ago_no_sentiment = last_date_no_sentiment - pd.DateOffset(months=1)

    # Filter data to get only the last three months without sentiment
    three_months_ago_no_sentiment = pd.Timestamp(three_months_ago_no_sentiment)
    crypto_data_last_month_no_sentiment = crypto_data_no_sentiment[crypto_data_no_sentiment['ds'] >= three_months_ago_no_sentiment]
    forecast_prophet_last_month_no_sentiment = forecast_prophet_no_sentiment[forecast_prophet_no_sentiment['ds'] >= three_months_ago_no_sentiment]

    # Visualize results without sentiment
    plt.figure(figsize=(10, 6))
    plt.plot(crypto_data_last_month_no_sentiment['ds'], crypto_data_last_month_no_sentiment['y'], color='gray', label='History')
    plt.plot(forecast_prophet_last_month_no_sentiment['ds'], forecast_prophet_last_month_no_sentiment['yhat'], color='blue', label='Forecast')
    plt.xlabel('Date')
    plt.ylabel('Closing Price')
    plt.title(f'Price Forecast of {crypto_code} using Prophet without Sentiment')
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# 20:33:09 - cmdstanpy - INFO - Chain [1] start processing
# 20:33:09 - cmdstanpy - INFO - Chain [1] done processing
# BTC-USD - MAE: 40781.7157948817
# BTC-USD - RMSE: 40788.70361113198
# BTC-USD - MAPE: 59.52944875070274
#   0%|          | 0/2 [00:00<?, ?it/s]
# 20:33:09 - cmdstanpy - INFO - Chain [1] start processing
# 20:33:09 - cmdstanpy - INFO - Chain [1] done processing
# 20:33:10 - cmdstanpy - INFO - Chain [1] start processing
# 20:33:10 - cmdstanpy - INFO - Chain [1] done processing
#   horizon           mse         rmse          mae      mape     mdape  \
# 0  2 days  2.457714e+07  4957.533914  3658.383585  0.069573  0.013198
# 1  3 days  2.371325e+07  4869.625148  3991.429445  0.074214  0.028157
# 2  4 days  2.547156e+07  5046.935645  4396.876184  0.080448  0.029026
# 3  5 days  2.324229e+07  4821.026340  4026.888210  0.074622  0.029026
# 4  6 days  3.424064e+07  5851.549798  5502.931961  0.094555  0.082986
#
#       smape  coverage
# 0  0.074418  0.500000
# 1  0.078828  0.500000
# 2  0.085337  0.500000
# 3  0.079143  0.500000
# 4  0.100164  0.166667
# 20:33:11 - cmdstanpy - INFO - Chain [1] start processing
# 20:33:11 - cmdstanpy - INFO - Chain [1] done processing
# ETH-USD - MAE: 1902.7366398191027
# ETH-USD - RMSE: 1903.7998726512656
# ETH-USD - MAPE: 50.10656211185617
#   0%|          | 0/2 [00:00<?, ?it/s]
# 20:33:11 - cmdstanpy - INFO - Chain [1] start processing
# 20:33:11 - cmdstanpy - INFO - Chain [1] done processing
# 20:33:12 - cmdstanpy - INFO - Chain [1] start processing
# 20:33:12 - cmdstanpy - INFO - Chain [1] done processing
#   horizon            mse        rmse         mae      mape     mdape  \
# 0  2 days   56174.217043  237.011006  202.093924  0.071190  0.038003
# 1  3 days   48638.089363  220.540448  187.877714  0.066291  0.038003
# 2  4 days   68531.065242  261.784387  220.474878  0.076044  0.031242
# 3  5 days   94648.457101  307.649894  243.833820  0.082828  0.031242
# 4  6 days  254219.844646  504.202186  462.632381  0.141694  0.170327
#
#       smape  coverage
# 0  0.074433  0.500000
# 1  0.069312  0.500000
# 2  0.080480  0.500000
# 3  0.088776  0.500000
# 4  0.154497  0.166667
# 20:33:13 - cmdstanpy - INFO - Chain [1] start processing
# 20:33:13 - cmdstanpy - INFO - Chain [1] done processing
# ADA-USD - MAE: 0.142210675511832
# ADA-USD - RMSE: 0.14232079628501182
# ADA-USD - MAPE: 30.894565367936593
#   0%|          | 0/2 [00:00<?, ?it/s]
# 20:33:13 - cmdstanpy - INFO - Chain [1] start processing
# 20:33:13 - cmdstanpy - INFO - Chain [1] done processing
# 20:33:13 - cmdstanpy - INFO - Chain [1] start processing
# 20:33:13 - cmdstanpy - INFO - Chain [1] done processing
#   horizon       mse      rmse       mae      mape     mdape     smape  \
# 0  2 days  0.003871  0.062219  0.049491  0.085299  0.030713  0.091120
# 1  3 days  0.004719  0.068698  0.061421  0.108498  0.085494  0.115925
# 2  4 days  0.006368  0.079799  0.073624  0.129320  0.091870  0.139254
# 3  5 days  0.007585  0.087094  0.077473  0.133382  0.091870  0.144683
# 4  6 days  0.008541  0.092418  0.086784  0.150887  0.135973  0.164245
#
#    coverage
# 0  0.500000
# 1  0.500000
# 2  0.500000
# 3  0.500000
# 4  0.166667
